# %% [markdown]
# 1. Design a registration form using tkinter

# %%
from tkinter import *

root=Tk()
root.geometry('900x720')
root.title('STUDENT REGISTRATION FORM')
root.configure(bg='lightblue1')

label0= Label(root,text='STUDENT REGISTRATION FORM',fg='skyblue2',bg='white',font=('Arial',20))
label0.place(x=50,y=50)

#First Name

label1= Label(root,text='FIRST NAME',fg='white',bg='skyblue2',font=('bold',10))
label1.place(x=20,y=100)

entry1= Entry(root)
entry1.place(x=170,y=100)

label01= Label(root,text='(max 30 characters a-z and A-Z)',fg='white',bg='skyblue2',font=('bold',10))
label01.place(x=350,y=100)


#Last Name

label2= Label(root,text='LAST NAME',fg='white',bg='skyblue2',font=('bold',10))
label2.place(x=20,y=125)

entry2= Entry(root)
entry2.place(x=170,y=125)

label02= Label(root,text='(max 30 characters a-z and A-Z)',fg='white',bg='skyblue2',font=('bold',10))
label02.place(x=350,y=125)


#date of birth

label3= Label(root,text='DATE OF BIRTH',fg='white',bg='skyblue2',font=('bold',10))
label3.place(x=20,y=150)

#entry3= OptionMenu(master, variable, value)

#email id

label4= Label(root,text='EMAIL ID',fg='white',bg='skyblue2',font=('bold',10))
label4.place(x=20,y=175)

entry4= Entry(root)
entry4.place(x=170,y=175)


#mobile

label5= Label(root,text='MOBILE NUMBER',fg='white',bg='skyblue2',font=('bold',10))
label5.place(x=20,y=200)

entry5= Entry(root)
entry5.place(x=170,y=200)

label05= Label(root,text='(10 digit number)',fg='white',bg='skyblue2',font=('bold',10))
label05.place(x=350,y=200)


#gender
    

gen = IntVar()
label5= Label(root,text='GENDER',fg='white',bg='skyblue2',font=('bold',10))
label5.place(x=20,y=225)

entry5= Radiobutton(root,text='Male',variable=gen,value=1,fg='white',bg='skyblue2',font=('bold',10))
entry5.place(x=170,y=225)

entry05= Radiobutton(root,text='Female',variable=gen,value=2,fg='white',bg='skyblue2',font=('bold',10))
entry05.place(x=250,y=225)


#address

label6= Label(root,text='ADDRESS',fg='white',bg='skyblue2',font=('bold',10))
label6.place(x=20,y=250)

entry6= Text(root,height=5,width=30)
entry6.place(x=170,y=250)


#city

label7= Label(root,text='CITY',fg='white',bg='skyblue2',font=('bold',10))
label7.place(x=20,y=350)

entry7= Entry(root)
entry7.place(x=170,y=350)

label07= Label(root,text='(max 30 characters a-z and A-Z)',fg='white',bg='skyblue2',font=('bold',10))
label07.place(x=350,y=350)


#pincode

label8= Label(root,text='PIN CODE',fg='white',bg='skyblue2',font=('bold',10))
label8.place(x=20,y=375)

entry8= Entry(root)
entry8.place(x=170,y=375)

label08= Label(root,text='(6 digit number)',fg='white',bg='skyblue2',font=('bold',10))
label08.place(x=350,y=375)


#state

label9= Label(root,text='STATE',fg='white',bg='skyblue2',font=('bold',10))
label9.place(x=20,y=400)

entry9= Entry(root)
entry9.place(x=170,y=400)

label09= Label(root,text='(max 30 characters a-z and A-Z)',fg='white',bg='skyblue2',font=('bold',10))
label09.place(x=350,y=400)


#country

label10= Label(root,text='COUNTRY',fg='white',bg='skyblue2',font=('bold',10))
label10.place(x=20,y=425)

entry10= Entry(root)
entry10.insert(0, "India")
entry10.place(x=170,y=425)


#hobbies

label11= Label(root, text="HOBBIES", fg='white', bg='skyblue2')
label11.place(x=20,y=450)

var1 = IntVar()
button1=Checkbutton(root, text="Drawing", variable=var1, fg='white', bg='skyblue2')
button1.place(x=170,y=450)
var2 = IntVar()
button2=Checkbutton(root, text="Singing", variable=var2, fg='white', bg='skyblue2')
button2.place(x=250,y=450)
var3 = IntVar()
button3=Checkbutton(root, text="Dancing", variable=var3, fg='white', bg='skyblue2')
button3.place(x=320,y=450)
var4 = IntVar()
button4=Checkbutton(root, text="Sketching", variable=var4, fg='white', bg='skyblue2')
button4.place(x=390,y=450)
var5 = IntVar()
button5=Checkbutton(root, text="Others", variable=var5, fg='white', bg='skyblue2')
button5.place(x=170,y=475)
state=Entry(root)
state.place(x=250,y=475)


#qualification

label12= Label(root, text="QUALIFICATION", fg='white', bg='skyblue2')
label12.place(x=20,y=500)

label1201= Label(root, text="SLNo.", fg='white', bg='skyblue2')
label1201.place(x=170,y=500)

label1202= Label(root, text="1", fg='white', bg='skyblue2')
label1202.place(x=170,y=525)
label1203= Label(root, text="2", fg='white', bg='skyblue2')
label1203.place(x=170,y=550)
label1204= Label(root, text="3", fg='white', bg='skyblue2')
label1204.place(x=170,y=575)
label1205= Label(root, text="4", fg='white', bg='skyblue2')
label1205.place(x=170,y=600)

label1206= Label(root, text="EXAMINATION", fg='white', bg='skyblue2')
label1206.place(x=250,y=500)
label1207= Label(root, text="Class X", fg='white', bg='skyblue2')
label1207.place(x=250,y=525)
label1208= Label(root, text="Class XII", fg='white', bg='skyblue2')
label1208.place(x=250,y=550)
label1209= Label(root, text="Graduation", fg='white', bg='skyblue2')
label1209.place(x=250,y=575)
label12010= Label(root, text="Masters", fg='white', bg='skyblue2')
label12010.place(x=250,y=600)


label1210= Label(root, text="BOARD", fg='white', bg='skyblue2')
label1210.place(x=350,y=500)
entry1201= Entry(root)
entry1201.place(x=350,y=525)
entry1202= Entry(root)
entry1202.place(x=350,y=550)
entry1203= Entry(root)
entry1203.place(x=350,y=575)
entry1204= Entry(root)
entry1204.place(x=350,y=600)

label1211= Label(root, text="PERCENTAGE", fg='white', bg='skyblue2')
label1211.place(x=500,y=500)
entry1211= Entry(root)
entry1211.place(x=500,y=525)
entry1212= Entry(root)
entry1212.place(x=500,y=550)
entry1213= Entry(root)
entry1213.place(x=500,y=575)
entry1214= Entry(root)
entry1214.place(x=500,y=600)

label1212= Label(root, text="YEAR OF PASSING", fg='white', bg='skyblue2')
label1212.place(x=650,y=500)
entry1221= Entry(root)
entry1221.place(x=650,y=525)
entry1222= Entry(root)
entry1222.place(x=650,y=550)
entry1223= Entry(root)
entry1223.place(x=650,y=575)
entry1224= Entry(root)
entry1224.place(x=650,y=600)


#courses
course = IntVar()
label13= Label(root,text='COURSES',fg='white',bg='skyblue2',font=('bold',10))
label130= Label(root,text='APPLIED FOR',fg='white',bg='skyblue2',font=('bold',10))
label13.place(x=20,y=625)
label130.place(x=20,y=645)

entry1301= Radiobutton(root,text='BCA',variable=course,value=1,fg='white',bg='skyblue2',font=('bold',10))
entry1301.place(x=170,y=625)

entry1302= Radiobutton(root,text='B.Com',variable=course,value=2,fg='white',bg='skyblue2',font=('bold',10))
entry1302.place(x=250,y=625)

entry1303= Radiobutton(root,text='B.Sc',variable=course,value=2,fg='white',bg='skyblue2',font=('bold',10))
entry1303.place(x=320,y=625)

entry1304= Radiobutton(root,text='B.A',variable=course,value=2,fg='white',bg='skyblue2',font=('bold',10))
entry1304.place(x=390,y=625)

#submit and reset
MyButton1 = Button(root, text="Submit", width=10)
MyButton1.place(x=390,y=675)

MyButton2 = Button(root, text="Reset", width=10)
MyButton2.place(x=500,y=675)


root.mainloop()

# %% [markdown]
# 2. Create a Registration form for Job Portal USING TKINTER

# %%
from tkinter import *
from tkinter import filedialog

root=Tk()
root.geometry('600x900')
root.title('Job Application')
root.configure(bg='mistyrose2')

label0= Label(root,text='Job Application',fg='black',bg='white',font=('Times New Roman',20,'bold'))
label0.place(x=100,y=20)

labelT1 = Label(root,text="Personal Information",fg='red4',bg='white',font=('Times New Roman',15))
labelT1.place(x=20,y=60)

#name

label1= Label(root,text='Name',fg='black',bg='white',font=('Aries',10))
label1.place(x=20,y=100)

entry1= Entry(root,bd=2)
entry1.place(x=170,y=100)
entry01= Entry(root,bd=2)
entry01.place(x=320,y=100)

#email

label2= Label(root,text='Email',fg='black',bg='white',font=('Aries',10))
label2.place(x=20,y=125)

entry2= Entry(root,bd=2, width= 45)
entry2.place(x=170,y=125)

#education

label3= Label(root,text='Education',fg='black',bg='white',font=('Aries',10))
label3.place(x=20,y=150)

edu= ["Under Graduation","Graduation","Post Graduation"]
clicked = StringVar()
clicked.set("Please Choose")
entry3= OptionMenu(root,clicked,*edu)
entry3.config(bg="white")
entry3.place(x=170,y=150)

#resume

label4= Label(root,text='Resume',fg='black',bg='white',font=('Aries',10))
label4.place(x=20,y=175)

b=Button(root, text='Choose file',fg='black',bg='white',font=('Aries',10))
b.place(x=170,y= 175)
location = filedialog.askopenfilename()

#Adress
label5= Label(root,text='Address',fg='black',bg='white',font=('Aries',10))
label5.place(x=20,y=200)

entry6= Text(root,height= 1, bd=2,width=35)
entry6.place(x=170,y=200)
entry7= Text(root,height= 1, bd=2,width=35)
entry7.place(x=170,y=225)
country= ["India","United States of America","China","Russia","Europe"]
clicked = StringVar()
clicked.set("Select a Country")
entry8= OptionMenu(root,clicked,*country)
entry8.config(bg="white")
entry8.place(x=170,y=250)
entry9= Text(root,height= 1, bd=2,width=20)
entry9.place(x=170,y=285)
entry10= Text(root,height= 1, bd=2,width=10)
entry10.place(x=340,y=285)
entry10= Text(root,height= 1, bd=2,width=15)
entry10.place(x=430,y=285)

#phone number
label5= Label(root,text='Phone Number',fg='black',bg='white',font=('Aries',10))
label5.place(x=20,y=325)
entry11= Text(root,height= 1, bd=2,width=5)
entry11.place(x=170,y=325)
entry12= Text(root,height= 1, bd=2,width=20)
entry12.place(x=220,y=325)

#Hobbies
label5= Label(root,text='What are your Hobbies?',fg='black',bg='white',font=('Aries',10))
label5.place(x=20,y=350)
entry12= Text(root,height= 2, bd=2,width=68)
entry12.place(x=20,y=375)


#Part2
labelT2 = Label(root,text="Previous/Current Employment",fg='red4',bg='white',font=('Times New Roman',15))
labelT2.place(x=20,y=425)

#Company Name
label5= Label(root,text='Company Name',fg='black',bg='white',font=('Aries',10))
label5.place(x=20,y=450)
entry13= Text(root,height=1, bd=2,width=40)
entry13.place(x=170,y=450)

#Job title
label6= Label(root,text='Job Title',fg='black',bg='white',font=('Aries',10))
label6.place(x=20,y=475)
entry14= Text(root,height=1, bd=2,width=40)
entry14.place(x=170,y= 475)

#Duration
label6= Label(root,text='How long were you',fg='black',bg='white',font=('Aries',10))
label6.place(x=20,y=500)
label6= Label(root,text='there?',fg='black',bg='white',font=('Aries',10))
label6.place(x=20,y=520)
entry14= Text(root,height=1, bd=2,width=40)
entry14.place(x=170,y=500)


#Part3
labelT3 = Label(root,text="Reference #1",fg='red4',bg='white',font=('Times New Roman',15))
labelT3.place(x=20,y=525)
#Name
label6= Label(root,text='Name',fg='black',bg='white',font=('Aries',10))
label6.place(x=20,y=550)
entry14= Text(root,height=1, bd=2,width=25)
entry14.place(x=170,y=550)
#Phone
label6= Label(root,text='Phone',fg='black',bg='white',font=('Aries',10))
label6.place(x=20,y=575)
entry14= Text(root,height=1, bd=2,width=25)
entry14.place(x=170,y=575)


#Part4
labelT3 = Label(root,text="Reference #2",fg='red4',bg='white',font=('Times New Roman',15))
labelT3.place(x=20,y=600)
#Name
label6= Label(root,text='Name',fg='black',bg='white',font=('Aries',10))
label6.place(x=20,y=625)
entry14= Text(root,height=1, bd=2,width=25)
entry14.place(x=170,y=625)
#Phone
label6= Label(root,text='Phone',fg='black',bg='white',font=('Aries',10))
label6.place(x=20,y=650)
entry14= Text(root,height=1, bd=2,width=25)
entry14.place(x=170,y=650)

b=Button(root, text='Apply',fg='white',bg='red4',font=('Aries',10))
b.place(x=375,y= 675)
root.mainloop()

# %% [markdown]
# 3. CONVERT THE FOLLOWING MANUAL FORM INTO DIGITAL MODE USING TKINTER

# %%
from tkinter import *

root = Tk()
root.geometry('900x500')
root.title('Registration Form')
root.configure(bg='darkseagreen1')

#heading
labelT = Label(root,text='REGISTRATION INFORMATION',bg='slategray2',font=('Aries',12,'bold'))
labelT.place(x=300,y=10)

#period
label1=Label(root,text='Registration Period: (check one)',bg='darkseagreen1',font=('Times New Roman',10,'bold'))
label1.place(x=20,y=50)
entry10=Checkbutton(root,text='One Year',bg='darkseagreen1')
entry10.place(x=230,y=50)
entry11= Checkbutton(root,text='Two Years',bg='darkseagreen1')
entry11.place(x=310,y=50)
entry12=Checkbutton(root,text='Three Years',bg='darkseagreen1')
entry12.place(x=400,y=50)


#type
label2=Label(root,text='Registration Type: (check one)',bg='darkseagreen1',font=('Times New Roman',10,'bold'))
label2.place(x=20,y=75)
entry20=Checkbutton(root,text='Original',bg='darkseagreen1')
entry20.place(x=230,y=75)
entry21= Checkbutton(root,text='Renewal',bg='darkseagreen1')
entry21.place(x=310,y=75)
entry22=Checkbutton(root,text='Private',bg='darkseagreen1')
entry22.place(x=400,y=75)
entry23=Checkbutton(root,text='Reissue(Plates and Decals)',bg='darkseagreen1')
entry23.place(x=490,y=75)

entry24=Checkbutton(root,text='Reissue(Decals only)',bg='darkseagreen1')
entry24.place(x=230,y=100)
entry25=Checkbutton(root,text='Rental Vehicle',bg='darkseagreen1')
entry25.place(x=370,y=100)
entry26=Checkbutton(root,text='Transfer License Plate number:',bg='darkseagreen1')
entry26.place(x=500,y=100)
entry27=Entry(root,width='15')
entry27.place(x=700,y=100)

entry28=Checkbutton(root,text='For Hire',bg='darkseagreen1')
entry28.place(x=230,y=125)
entry29=Checkbutton(root,text='Ridesharing(Carpool)',bg='darkseagreen1')
entry29.place(x=370,y=125)
entry211=Entry(root,text='Seating Capacity',width='5')
entry211.place(x=520,y=125)

entry212=Checkbutton(root,text='Amateur Radio Operator Call Letters- Specify Letters:',bg='darkseagreen1')
entry212.place(x=230,y=150)
entry213=Entry(root,width='10')
entry213.place(x=535,y=150)
entry214=Checkbutton(root,text='Other:',bg='darkseagreen1')
entry214.place(x=630,y=150)
entry215=Entry(root,width='15')
entry215.place(x=690,y=150)


#heading 2
labelT2 = Label(root,text='OWNER INFORMATION',bg='slategray2',font=('Aries',12,'bold'))
labelT2.place(x=300,y=200)

#line1
label3=Label(root,text="Owner's Full Name:",bg='darkseagreen1',font=('Times New Roman',10))
label3.place(x=20,y=225)
entry3=Entry(root)
entry3.place(x=150,y=225)

label31=Label(root,text="Telephone Number:",bg='darkseagreen1',font=('Times New Roman',10))
label31.place(x=290,y=225)
entry31=Entry(root)
entry31.place(x=400,y=225)

#line2

label4=Label(root,text="Co-owner's Full Name:",bg='darkseagreen1',font=('Times New Roman',10))
label4.place(x=20,y=250)
entry4=Entry(root)
entry4.place(x=150,y=250)

label41=Label(root,text="Telephone Number:",bg='darkseagreen1',font=('Times New Roman',10))
label41.place(x=290,y=250)
entry41=Entry(root)
entry41.place(x=400,y=250)

#line3

label5=Label(root,text="Owner's Residencial Address:",bg='darkseagreen1',font=('Times New Roman',10))
label5.place(x=20,y=275)
entry5=Entry(root)
entry5.place(x=190,y=275)

label51=Label(root,text="City:",bg='darkseagreen1',font=('Times New Roman',10))
label51.place(x=330,y=275)
entry51=Entry(root)
entry51.place(x=360,y=275)

label52=Label(root,text="State:",bg='darkseagreen1',font=('Times New Roman',10))
label52.place(x=500,y=275)
entry52=Entry(root,width='5')
entry52.place(x=550,y=275)

label53=Label(root,text="Zip Code:",bg='darkseagreen1',font=('Times New Roman',10))
label53.place(x=600,y=275)
entry53=Entry(root,width='5')
entry53.place(x=660,y=275)


#line 4

label6=Label(root,text="Owner's Email Address:",bg='darkseagreen1',font=('Times New Roman',10))
label6.place(x=20,y=300)
entry6=Entry(root)
entry6.place(x=150,y=300)

label61=Label(root,text="Co-owner's Email Address:",bg='darkseagreen1',font=('Times New Roman',10))
label61.place(x=300,y=300)
entry61=Entry(root)
entry61.place(x=450,y=300)


#heading3

labelT3 = Label(root,text='ADDITIONAL INFORMATION',bg='slategray2',font=('Aries',12,'bold'))
labelT3.place(x=300,y=350)

#line1
label3=Label(root,text="Location where vehicle is principally garaged:",bg='darkseagreen1',font=('Times New Roman',10))
label3.place(x=20,y=375)
btn1=Checkbutton(root,text='City',bg='darkseagreen1')
btn1.place(x=20,y=400)
btn2=Checkbutton(root,text='Country',bg='darkseagreen1')
btn2.place(x=80,y=400)
entry3=Entry(root)
entry3.place(x=160,y=400)

label31=Label(root,text='If new Location enter date changed',bg='darkseagreen1',font=('Times New Roman',10))
label31.place(x=450,y=375)
entry31=Entry(root,width='15')
entry31.place(x=650,y=375)



root.mainloop()

# %% [markdown]
# 4. Design a registration form for hotel room accommodation by converting this manual from
# into digital format using tkinter

# %%
from tkinter import *
from tkinter import filedialog

root=Tk()
root.title("HOTEL ROOM ACCOMMODATION")
root.geometry('900x750')
root.configure(bg='ivory2')

labelT = Label(root,text='HOTEL ROOM ACCOMMODATION',bg='ivory3',font=('Aries',12,'bold'))
labelT.place(x=300,y=10)

#Title
label1= Label(root,text='Title',fg='black',bg='ivory2',font=('Aries',10))
label1.place(x=10,y=100)
entry1= Text(root, height=1, bd=2)
entry1.place(x=140,y=100)

#Names
label1= Label(root,text='Last Name',fg='black',bg='ivory2',font=('Aries',10))
label1.place(x=10,y=125)
entry1= Text(root, height=1, bd=2)
entry1.place(x=140,y=125)
label1= Label(root,text='First Name(s)',fg='black',bg='ivory2',font=('Aries',10))
label1.place(x=10,y=150)
entry1= Text(root, height=1, bd=2)
entry1.place(x=140,y=150)

#contact
label1= Label(root,text='Share with',fg='black',bg='ivory2',font=('Aries',10))
label1.place(x=10,y=175)
entry1= Text(root, height=1, bd=2)
entry1.place(x=140,y=175)
label1= Label(root,text='Business Number',fg='black',bg='ivory2',font=('Aries',10))
label1.place(x=10,y=200)
entry1= Text(root, height=1, bd=2)
entry1.place(x=140,y=200)
label1= Label(root,text='Mobile Number',fg='black',bg='ivory2',font=('Aries',10))
label1.place(x=10,y=225)
entry1= Text(root, height=1, bd=2)
entry1.place(x=140,y=225)
label1= Label(root,text='Email',fg='black',bg='ivory2',font=('Aries',10))
label1.place(x=10,y=250)
entry1= Text(root, height=1, bd=2)
entry1.place(x=140,y=250)

#ETA
label1= Label(root,text='Date of Arrival',fg='black',bg='ivory2',font=('Aries',10))
label1.place(x=10,y=275)
entry1= Text(root, height=1, bd=2)
entry1.place(x=140,y=275)
label1= Label(root,text='Date of Departure',fg='black',bg='ivory2',font=('Aries',10))
label1.place(x=10,y=300)
entry1= Text(root, height=1, bd=2)
entry1.place(x=140,y=300)

#Payment
label1= Label(root,text='Name on Credit card',fg='black',bg='ivory2',font=('Aries',10))
label1.place(x=10,y=325)
entry1= Text(root, height=1, bd=2)
entry1.place(x=140,y=325)
label1= Label(root,text='No. on Credit Card',fg='black',bg='ivory2',font=('Aries',10))
label1.place(x=10,y=350)
entry1= Text(root, height=1, bd=2)
entry1.place(x=140,y=350)
label1= Label(root,text='Expiry Date',fg='black',bg='ivory2',font=('Aries',10))
label1.place(x=10,y=375)
entry1= Text(root, height=1, bd=2)
entry1.place(x=140,y=375)
label1= Label(root,text='CVV Number',fg='black',bg='ivory2',font=('Aries',10))
label1.place(x=10,y=400)
entry1= Text(root, height=1, bd=2)
entry1.place(x=140,y=400)
label1= Label(root,text='Payment Method',fg='black',bg='ivory2',font=('Aries',10))
label1.place(x=10,y=425)
Paymentgateway = IntVar()
entry1302= Radiobutton(root,text='Credit card',variable=Paymentgateway,value=1,fg='black',bg='ivory2',font=('bold',10))
entry1302.place(x=140,y=425)
entry1303= Radiobutton(root,text='Direct bank transfer',variable=Paymentgateway,value=2,fg='black',bg='ivory2',font=('bold',10))
entry1303.place(x=250,y=425)


#section 2

label2= Label(root,text="Negotiated Rates:",fg='black',bg='ivory2',font=('Aries',12))
label2.place(x=10,y=450)

label31= Checkbutton(root,text='Deluxe Room Single',fg='black',bg='ivory2',font=('Aries',10))
label31.place(x=20,y=475)
label32= Label(root,text='Rs 1700',fg='black',bg='ivory2',font=('Aries',10))
label32.place(x=200,y=475)
label33= Checkbutton(root,text='Deluxe Room Double',fg='black',bg='ivory2',font=('Aries',10))
label33.place(x=420,y=475)
label34= Label(root,text='Rs 1700',fg='black',bg='ivory2',font=('Aries',10))
label34.place(x=600,y=475)
label41= Checkbutton(root,text='Suites Room Single',fg='black',bg='ivory2',font=('Aries',10))
label41.place(x=20,y=500)
label42= Label(root,text='Rs 1700',fg='black',bg='ivory2',font=('Aries',10))
label42.place(x=200,y=500)
label43= Checkbutton(root,text='Suites Room Double',fg='black',bg='ivory2',font=('Aries',10))
label43.place(x=420,y=500)
label44= Label(root,text='Rs 1700',fg='black',bg='ivory2',font=('Aries',10))
label44.place(x=600,y=500)


#section 3

label5= Label(root,text="Room Preference:",fg='black',bg='ivory2',font=('Aries',12))
label5.place(x=10,y=525)

label51= Checkbutton(root,text='King Bed',fg='black',bg='ivory2',font=('Aries',10))
label51.place(x=20,y=550)
label52= Checkbutton(root,text='Twin - Two SIngle Beds',fg='black',bg='ivory2',font=('Aries',10))
label52.place(x=420,y=550)

#section 4

label6 = Label(root,text='Signature',fg='black',bg='ivory2',font=('Aries',10))
label6.place(x=10,y=600)
entry6 = Entry(root)
entry6.place(x=100,y=600)
label7 = Label(root,text='Name',fg='black',bg='ivory2',font=('Aries',10))
label7.place(x=420,y=600)
entry7 = Entry(root)
entry7.place(x=500,y=600)

label8 = Label(root,text='Date',fg='black',bg='ivory2',font=('Aries',10))
label8.place(x=10,y=625)
entry8 = Entry(root)
entry8.place(x=100,y=625)

btn=Button(root,text= 'Submit',fg='black',bg='azure3',font=('Aries',10))
btn.place(x=350,y=675)

root.mainloop()

# %% [markdown]
# 5. Design a GUI using tkinter for CAB Rental booking.

# %%
from tkinter import *

root=Tk()
root.geometry('750x850')
root.title("CAB Rental")
root.configure(bg="white")

labelT1= Label(root,text="CAR RENTAL RECEIPT",bg="grey4",fg="yellow",font=("Times New Roman",18,"bold"),height=1,width=700)
labelT1.pack()

#Date

label0= Label(root,text="Date:",bg="white")
label0.place(x=10,y=60)

entry0= Entry(root,bg="white",fg="black")
entry0.place(x=70 ,y=60)

#Receipt

label1= Label(root,text="Receipt #:",bg="white")
label1.place(x=10,y=90)

entry0= Entry(root,bg="white",fg="black")
entry0.place(x=70 ,y=90)

#Rental Company Info

labelT2= Label(root,text="Rental Company Info",bg="white",font=("Times New Roman",12,"bold"))
labelT2.place(x=10,y=120)

label2= Label(root,text="Company:",bg="white")
label2.place(x=10,y=150)
entry0= Entry(root,bg="white",fg="black")
entry0.place(x=100 ,y=150)

label2= Label(root,text="Representative:",bg="white")
label2.place(x=10,y=180)
entry0= Entry(root,bg="white",fg="black")
entry0.place(x=100 ,y=180)

label2= Label(root,text="Location:",bg="white")
label2.place(x=10,y=210)
entry0= Entry(root,bg="white",fg="black")
entry0.place(x=100 ,y=210)

label2= Label(root,text="City/State/ZIP:",bg="white")
label2.place(x=10,y=240)
entry0= Entry(root,bg="white",fg="black")
entry0.place(x=100 ,y=240)

label2= Label(root,text="Phone:",bg="white")
label2.place(x=10,y=270)
entry0= Entry(root,bg="white",fg="black")
entry0.place(x=100 ,y=270)

#underline in rental company info

#Lessee Info
labelT3= Label(root,text="Lessee Info",bg="white",font=("Times New Roman",12,"bold"))
labelT3.place(x=350,y=120)

label2= Label(root,text="Name:",bg="white")
label2.place(x=350,y=150)
entry0= Entry(root,bg="white",fg="black")
entry0.place(x=440 ,y=150)

label2= Label(root,text="License #",bg="white")
label2.place(x=350,y=180)
entry0= Entry(root,bg="white",fg="black")
entry0.place(x=440 ,y=180)

label2= Label(root,text="Address:",bg="white")
label2.place(x=350,y=210)
entry0= Entry(root,bg="white",fg="black")
entry0.place(x=440 ,y=210)

label2= Label(root,text="City/State/ZIP:",bg="white")
label2.place(x=350,y=240)
entry0= Entry(root,bg="white",fg="black")
entry0.place(x=440 ,y=240)

label2= Label(root,text="Phone:",bg="white")
label2.place(x=350,y=270)
entry0= Entry(root,bg="white",fg="black")
entry0.place(x=440 ,y=270)


#Vehicle Information

labelT3= Label(root,text="Vehicle Information",bg="white",font=("Times New Roman",16,"bold"))
labelT3.place(x=180,y=310)

#Left Side

label2= Label(root,text="VIN:",bg="white")
label2.place(x=10,y=350)
entry0= Entry(root,bg="white",fg="black")
entry0.place(x=70 ,y=350)

label2= Label(root,text="Make:",bg="white")
label2.place(x=10,y=380)
entry0= Entry(root,bg="white",fg="black")
entry0.place(x=70 ,y=380)

label2= Label(root,text="Year:",bg="white")
label2.place(x=10,y=410)
entry0= Entry(root,bg="white",fg="black")
entry0.place(x=70 ,y=410)

label2= Label(root,text="Color:",bg="white")
label2.place(x=10,y=440)
entry0= Entry(root,bg="white",fg="black")
entry0.place(x=70 ,y=440)

#Right Side

label2= Label(root,text="Registration #",bg="white")
label2.place(x=250,y=350)
entry0= Entry(root,bg="white",fg="black")
entry0.place(x=340 ,y=350)

label2= Label(root,text="Model:",bg="white")
label2.place(x=250,y=380)
entry0= Entry(root,bg="white",fg="black")
entry0.place(x=340 ,y=380)

label2= Label(root,text="Mileage:",bg="white")
label2.place(x=250,y=410)
entry0= Entry(root,bg="white",fg="black")
entry0.place(x=340 ,y=410)
root.mainloop()
